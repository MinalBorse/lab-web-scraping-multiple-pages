# %%
#Find other lists of hot songs on the internet and scrape them too: having a bigger pool of songs will be awesome!
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import pandas as pd

# %%
#app > main > div.page-wrap.playlist_pg > div > section.song-list.sno.albCol > ul:nth-child(2) > li._wrap > div._grp

# %%
# 2. find url and store it in a variable
url = "http://www.popvortex.com/music/india/top-songs.php" #Indian Website

# %%
# 3. download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
#soup

# %%
# 5. retrieve/extract the desired info (here, you'll paste the "Selector" you copied before to get the element that belongs to the top movie)
soup.select("#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite")
#app > main > div.page-wrap.playlist_pg > div > section.song-list.sno.albCol > ul:nth-child(2) > li._wrap > div._grp
# Out:
# [<cite class="title">love nwantiti (feat. Axel &amp; DJ Yo) [Remix]</cite>]

# %%
soup.div.get_text()
# Out:
# 'Toggle navigation  Music Music News and ReviewsiTunes Music ChartsiTunes Top Song ChartsiTunes Top 100 SongsApple Top 200 StreamsTop Country SongsTop Pop SongsTop Rap SongsTop Alternative Songs iTunes Top Album ChartsiTunes Top 100 AlbumsTop Country AlbumsTop Pop AlbumsTop Rap AlbumsTop Alternative AlbumsInternational iTunes ChartsBooks Book News and ReviewsAudiobook Charts by GenreAudiobook BestsellersFiction Audiobook Best SellersNon-Fiction Audiobook Best SellersTop New AudiobooksEbook Best Seller Charts by GenreEbook Best SellersFiction Ebook Best SellersNon-Fiction Ebook Best SellersMovies Movie News, Revies & Box Office ReportsTop iTunes MoviesTelevision TV NewsTop TV EpisodesTop TV SeasonsApps Top Paid iPhone AppsTop Free iPhone AppsTop Paid iPad AppsTop Free iPad AppsTop Mac AppsTop Free Mac AppsWorld Charts\nHomeMusicMusic Charts International Charts\niTunes IndiaTop 100 SongsTweet \niTunes India Top 100 SongsChart lists of the top 100 songs downloaded at the Indian iTunes 
# ...

# %%
#initialize empty lists
title = []
artist = []


# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)
num_iter = len(soup.select("cite.title"))

# iterate through the result set and retrive all the data
for i in range(num_iter):
    title.append(soup.select("cite.title")[i].get_text())
    artist.append(soup.select("em.artist")[i].get_text())
    

#print(title)
#print(artist)

# each list becomes a column
songs = pd.DataFrame({"title":title,
                       "artist":artist
                      })

# %%
songs.head()
# Out:
#                                         title  \
# 0  love nwantiti (feat. Axel & DJ Yo) [Remix]
# 1                Jugnu (feat. Nikhita Gandhi)
# 2                            Raataan Lambiyan
# 3                               Bijlee Bijlee
# 4                                      Ranjha
#
#                                         artist
# 0                                         CKay
# 1                                      Badshah
# 2  Tanishk Bagchi, Jubin Nautiyal & Asees Kaur
# 3                                Harrdy Sandhu
# 4                     Jasleen Royal & B. Praak

# %%
#1Retrieve an arbitrary Wikipedia page of "Python" and create a list of links on that page: url ='https://en.wikipedia.org/wiki/Python'
#2Find the number of titles that have changed in the United States Code since its last release point: url = 'http://uscode.house.gov/download/download.shtml'
#3Create a Python list with the top ten FBI's Most Wanted names: url = 'https://www.fbi.gov/wanted/topten'
#4Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe: url = 'https://www.emsc-csem.org/Earthquake/'
#5List all language names and number of related articles in the order they appear in wikipedia.org: url = 'https://www.wikipedia.org/'
#6A list with the different kind of datasets available in data.gov.uk: url = 'https://data.gov.uk/'
#7Display the top 10 languages by number of native speakers stored in a pandas dataframe: url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers

# %%
#

# %%
#Retrieve an arbitrary Wikipedia page of "Python" and create a list of links on that page: url ='https://en.wikipedia.org/wiki/Python'
html = urlopen("https://en.wikipedia.org/wiki/Python")
list_python = BeautifulSoup(html)
for link in list_python.findAll("a"):
  if 'href' in link.attrs:
    print(link.attrs['href'])
# Out:
# #mw-head
# #searchInput
# https://en.wiktionary.org/wiki/Python
# https://en.wiktionary.org/wiki/python
# /wiki/Pythonidae
# /wiki/Python_(genus)
# #Computing
# #People
# #Roller_coasters
# #Vehicles
# #Weaponry
# #Other_uses
# #See_also
# /w/index.php?title=Python&action=edit&section=1
# /wiki/Python_(programming_language)
# /wiki/CMU_Common_Lisp
# /wiki/PERQ#PERQ_3
# /w/index.php?title=Python&action=edit&section=2
# /wiki/Python_of_Aenus
# /wiki/Python_(painter)
# /wiki/Python_of_Byzantium
# /wiki/Python_of_Catana
# /wiki/Python_Anghelo
# /w/index.php?title=Python&action=edit&section=3
# /wiki/Python_(Efteling)
# /wiki/Python_(Busch_Gardens_Tampa_Bay)
# /wiki/Python_(Coney_Island,_Cincinnati,_Ohio)
# /w/index.php?title=Python&action=edit&section=4
# /wiki/Python_(automobile_maker)
# /wiki/Python_(Ford_prototype)
# /w/index.php?title=Python&action=edit&section=5
# /wiki/Python_(missile)
# /wiki/Python_(nuclear_primary)
# /wiki/Colt_Python
# ...

# %%
#Display the top 10 languages by number of native speakers stored in a pandas dataframe: url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'
html = urlopen("https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers")
top_10 = BeautifulSoup(html)
for link in top_10.findAll("a"):
  if 'href' in link.attrs:
    print(link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #searchInput
# /wiki/List_of_languages_by_total_number_of_speakers
# /wiki/Lists_of_endangered_languages
# /wiki/File:Human_Language_Families.png
# /wiki/File:Human_Language_Families.png
# /wiki/Native_speaker
# /wiki/Dialect_continuum
# #cite_note-Paolillo&Das-1
# /wiki/Variety_(linguistics)
# /wiki/Mutually_intelligible
# /wiki/Danish_language
# /wiki/Norwegian_language
# #cite_note-2
# /wiki/German_language
# /wiki/Italian_language
# /wiki/English_language
# #cite_note-Paolillo&Das-1
# /wiki/Arabic_language
# /wiki/Modern_Standard_Arabic
# #cite_note-3
# /wiki/Chinese_language
# #cite_note-4
# /wiki/Mandarin_Chinese
# /wiki/Wu_Chinese
# /wiki/Yue_Chinese
# #cite_note-5
# /wiki/Language_shift
# /wiki/Census
# #cite_note-6
# #Top_languages_by_population
# #Ethnologue_(2019,_22nd_edition)
# #Nationalencyklopedin_(2010)
# #Charts_and_graphs
# #See_also
# #Notes
# #References
# #External_links
# /wiki/SIL_Ethnologue
# ...
